# %%
#%pip install git+https://github.com/MAAP-Project/stac_ipyleaflet.git#egg-info=stac_ipyleaflet
# Out:
# Collecting git+https://github.com/MAAP-Project/stac_ipyleaflet.git#egg-info=stac_ipyleaflet
#   Cloning https://github.com/MAAP-Project/stac_ipyleaflet.git to /tmp/pip-req-build-fuzi71qf
#   Running command git clone --filter=blob:none --quiet https://github.com/MAAP-Project/stac_ipyleaflet.git /tmp/pip-req-build-fuzi71qf
#   Resolved https://github.com/MAAP-Project/stac_ipyleaflet.git to commit a880a19ad8eafff605ca2c8895f07032733c6034
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: ipyleaflet>=0.17.2 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from stac_ipyleaflet==0.3.6) (0.19.2)
# Requirement already satisfied: ipywidgets>=8.0.4 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from stac_ipyleaflet==0.3.6) (8.1.3)
# Requirement already satisfied: ipyevents in /srv/conda/envs/notebook/lib/python3.11/site-packages (from stac_ipyleaflet==0.3.6) (2.0.2)
# Requirement already satisfied: matplotlib in /srv/conda/envs/notebook/lib/python3.11/site-packages (from stac_ipyleaflet==0.3.6) (3.9.1)
# Requirement already satisfied: pydantic in /srv/conda/envs/notebook/lib/python3.11/site-packages (from stac_ipyleaflet==0.3.6) (2.8.2)
# Requirement already satisfied: shapely in /srv/conda/envs/notebook/lib/python3.11/site-packages (from stac_ipyleaflet==0.3.6) (2.0.5)
# Requirement already satisfied: rasterio in /srv/conda/envs/notebook/lib/python3.11/site-packages (from stac_ipyleaflet==0.3.6) (1.3.10)
# Requirement already satisfied: requests in /srv/conda/envs/notebook/lib/python3.11/site-packages (from stac_ipyleaflet==0.3.6) (2.32.3)
# Requirement already satisfied: rio_tiler in /srv/conda/envs/notebook/lib/python3.11/site-packages (from stac_ipyleaflet==0.3.6) (7.2.2)
# Requirement already satisfied: rioxarray in /srv/conda/envs/notebook/lib/python3.11/site-packages (from stac_ipyleaflet==0.3.6) (0.17.0)
# Requirement already satisfied: xarray in /srv/conda/envs/notebook/lib/python3.11/site-packages (from stac_ipyleaflet==0.3.6) (2024.7.0)
# Requirement already satisfied: python-dotenv in /srv/conda/envs/notebook/lib/python3.11/site-packages (from stac_ipyleaflet==0.3.6) (1.0.1)
# Requirement already satisfied: pystac_client==0.6.1 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from stac_ipyleaflet==0.3.6) (0.6.1)
# Requirement already satisfied: pystac>=1.7.0 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from pystac_client==0.6.1->stac_ipyleaflet==0.3.6) (1.10.1)
# Requirement already satisfied: python-dateutil>=2.7.0 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from pystac_client==0.6.1->stac_ipyleaflet==0.3.6) (2.8.2)
# Requirement already satisfied: branca>=0.5.0 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from ipyleaflet>=0.17.2->stac_ipyleaflet==0.3.6) (0.7.2)
# Requirement already satisfied: jupyter-leaflet<0.20,>=0.19 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from ipyleaflet>=0.17.2->stac_ipyleaflet==0.3.6) (0.19.2)
# Requirement already satisfied: traittypes<3,>=0.2.1 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from ipyleaflet>=0.17.2->stac_ipyleaflet==0.3.6) (0.2.1)
# Requirement already satisfied: xyzservices>=2021.8.1 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from ipyleaflet>=0.17.2->stac_ipyleaflet==0.3.6) (2024.6.0)
# Requirement already satisfied: comm>=0.1.3 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from ipywidgets>=8.0.4->stac_ipyleaflet==0.3.6) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from ipywidgets>=8.0.4->stac_ipyleaflet==0.3.6) (8.17.2)
# Requirement already satisfied: traitlets>=4.3.1 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from ipywidgets>=8.0.4->stac_ipyleaflet==0.3.6) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.11 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from ipywidgets>=8.0.4->stac_ipyleaflet==0.3.6) (4.0.11)
# Requirement already satisfied: jupyterlab-widgets~=3.0.11 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from ipywidgets>=8.0.4->stac_ipyleaflet==0.3.6) (3.0.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from requests->stac_ipyleaflet==0.3.6) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from requests->stac_ipyleaflet==0.3.6) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from requests->stac_ipyleaflet==0.3.6) (1.26.19)
# Requirement already satisfied: certifi>=2017.4.17 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from requests->stac_ipyleaflet==0.3.6) (2024.7.4)
# Requirement already satisfied: contourpy>=1.0.1 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from matplotlib->stac_ipyleaflet==0.3.6) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from matplotlib->stac_ipyleaflet==0.3.6) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from matplotlib->stac_ipyleaflet==0.3.6) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from matplotlib->stac_ipyleaflet==0.3.6) (1.4.5)
# Requirement already satisfied: numpy>=1.23 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from matplotlib->stac_ipyleaflet==0.3.6) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from matplotlib->stac_ipyleaflet==0.3.6) (24.1)
# Requirement already satisfied: pillow>=8 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from matplotlib->stac_ipyleaflet==0.3.6) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from matplotlib->stac_ipyleaflet==0.3.6) (3.1.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from pydantic->stac_ipyleaflet==0.3.6) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from pydantic->stac_ipyleaflet==0.3.6) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from pydantic->stac_ipyleaflet==0.3.6) (4.12.2)
# Requirement already satisfied: affine in /srv/conda/envs/notebook/lib/python3.11/site-packages (from rasterio->stac_ipyleaflet==0.3.6) (2.4.0)
# Requirement already satisfied: attrs in /srv/conda/envs/notebook/lib/python3.11/site-packages (from rasterio->stac_ipyleaflet==0.3.6) (23.2.0)
# Requirement already satisfied: click>=4.0 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from rasterio->stac_ipyleaflet==0.3.6) (8.1.7)
# Requirement already satisfied: cligj>=0.5 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from rasterio->stac_ipyleaflet==0.3.6) (0.7.2)
# Requirement already satisfied: snuggs>=1.4.1 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from rasterio->stac_ipyleaflet==0.3.6) (1.4.7)
# Requirement already satisfied: click-plugins in /srv/conda/envs/notebook/lib/python3.11/site-packages (from rasterio->stac_ipyleaflet==0.3.6) (1.1.1)
# Requirement already satisfied: setuptools in /srv/conda/envs/notebook/lib/python3.11/site-packages (from rasterio->stac_ipyleaflet==0.3.6) (70.1.1)
# Requirement already satisfied: cachetools in /srv/conda/envs/notebook/lib/python3.11/site-packages (from rio_tiler->stac_ipyleaflet==0.3.6) (5.4.0)
# Requirement already satisfied: color-operations in /srv/conda/envs/notebook/lib/python3.11/site-packages (from rio_tiler->stac_ipyleaflet==0.3.6) (0.1.6)
# Requirement already satisfied: httpx in /srv/conda/envs/notebook/lib/python3.11/site-packages (from rio_tiler->stac_ipyleaflet==0.3.6) (0.27.0)
# Requirement already satisfied: morecantile<7.0,>=5.0 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from rio_tiler->stac_ipyleaflet==0.3.6) (6.2.0)
# Requirement already satisfied: numexpr in /srv/conda/envs/notebook/lib/python3.11/site-packages (from rio_tiler->stac_ipyleaflet==0.3.6) (2.10.2)
# Requirement already satisfied: pyproj>=3.3 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from rioxarray->stac_ipyleaflet==0.3.6) (3.6.1)
# Requirement already satisfied: pandas>=2.0 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from xarray->stac_ipyleaflet==0.3.6) (2.2.2)
# Requirement already satisfied: jinja2>=3 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from branca>=0.5.0->ipyleaflet>=0.17.2->stac_ipyleaflet==0.3.6) (3.1.4)
# Requirement already satisfied: decorator in /srv/conda/envs/notebook/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->stac_ipyleaflet==0.3.6) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->stac_ipyleaflet==0.3.6) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /srv/conda/envs/notebook/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->stac_ipyleaflet==0.3.6) (0.1.7)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->stac_ipyleaflet==0.3.6) (3.0.38)
# Requirement already satisfied: pygments>=2.4.0 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->stac_ipyleaflet==0.3.6) (2.18.0)
# Requirement already satisfied: stack-data in /srv/conda/envs/notebook/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->stac_ipyleaflet==0.3.6) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets>=8.0.4->stac_ipyleaflet==0.3.6) (4.9.0)
# Requirement already satisfied: pytz>=2020.1 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from pandas>=2.0->xarray->stac_ipyleaflet==0.3.6) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from pandas>=2.0->xarray->stac_ipyleaflet==0.3.6) (2024.1)
# Requirement already satisfied: six>=1.5 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from python-dateutil>=2.7.0->pystac_client==0.6.1->stac_ipyleaflet==0.3.6) (1.16.0)
# Requirement already satisfied: anyio in /srv/conda/envs/notebook/lib/python3.11/site-packages (from httpx->rio_tiler->stac_ipyleaflet==0.3.6) (4.4.0)
# Requirement already satisfied: httpcore==1.* in /srv/conda/envs/notebook/lib/python3.11/site-packages (from httpx->rio_tiler->stac_ipyleaflet==0.3.6) (1.0.5)
# Requirement already satisfied: sniffio in /srv/conda/envs/notebook/lib/python3.11/site-packages (from httpx->rio_tiler->stac_ipyleaflet==0.3.6) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from httpcore==1.*->httpx->rio_tiler->stac_ipyleaflet==0.3.6) (0.14.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=8.0.4->stac_ipyleaflet==0.3.6) (0.8.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from jinja2>=3->branca>=0.5.0->ipyleaflet>=0.17.2->stac_ipyleaflet==0.3.6) (2.1.5)
# Requirement already satisfied: ptyprocess>=0.5 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets>=8.0.4->stac_ipyleaflet==0.3.6) (0.7.0)
# Requirement already satisfied: wcwidth in /srv/conda/envs/notebook/lib/python3.11/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets>=8.0.4->stac_ipyleaflet==0.3.6) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=8.0.4->stac_ipyleaflet==0.3.6) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=8.0.4->stac_ipyleaflet==0.3.6) (2.4.1)
# Requirement already satisfied: pure-eval in /srv/conda/envs/notebook/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=8.0.4->stac_ipyleaflet==0.3.6) (0.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import stac_ipyleaflet

# %%
m = stac_ipyleaflet.StacIpyleaflet()
# Out:
# HBox(children=(ToggleButton(value=False, description='Interact', icon='pencil', layout=Layout(border_bottom='1…
# WARNING:root:Following environment variable(s) are missing ['TITILER_STAC_ENDPOINT', 'TITILER_ENDPOINT', 'STAC_CATALOG_NAME', 'STAC_CATALOG_URL']
#  To set these environment variables, run this code:
#
#  import os
#  os.environ['TITILER_STAC_ENDPOINT']='REPLACE_WITH_TITILER_STAC_URL'
# os.environ['TITILER_ENDPOINT']='REPLACE_WITH_TITILER_URL'
# os.environ['STAC_CATALOG_NAME']='REPLACE_WITH_NAME_OF_STAC_CATALOG'
# os.environ['STAC_CATALOG_URL']='REPLACE_WITH_URL_OF_STAC_CATALOG'
# Output()
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 m = stac_ipyleaflet.StacIpyleaflet()
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/stac_ipyleaflet/core.py:69, in StacIpyleaflet.__init__(self, **kwargs)
#      67 self.check_for_env_vars()
#      68 self.add_default_layer_options()
# ---> 69 self.add_custom_tools()
#      71 self.point_control = InspectControlWidget.template(self)
#      72 self.draw_control = DrawControlWidget.template(self)
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/stac_ipyleaflet/core.py:439, in StacIpyleaflet.add_custom_tools(self)
#     436 def add_custom_tools(self):
#     437     # Create custom map widgets
#     438     self.layers_widget = self.create_layers_widget()
# --> 439     self.stac_widget = StacDiscoveryWidget.template(self)
#     440     self.interact_widget = self.create_interact_widget()
#     442     layers_widget = VBox([self.layers_widget])
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/stac_ipyleaflet/stac_discovery/stac_widget.py:69, in StacDiscoveryWidget.template(self)
#      67 catalog_options = sorted([c["name"] for c in stac_catalogs])
#      68 for cat in stac_catalogs:
# ---> 69     stac_client = Client.open(cat["url"], headers=[])
#      70     collections_object = stac_client.get_all_collections()
#      71     collections, bad_collections = Stac.organize_collections(collections_object)
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/pystac_client/client.py:143, in Client.open(cls, url, headers, parameters, ignore_conformance, modifier, request_modifier, stac_io)
#      80 @classmethod
#      81 def open(
#      82     cls,
#    (...)
#      89     stac_io: Optional[StacApiIO] = None,
#      90 ) -> "Client":
#      91     """Opens a STAC Catalog or API
#      92     This function will read the root catalog of a STAC Catalog or API
#      93
#    (...)
#     141         catalog : A :class:`Client` instance for this Catalog/API
#     142     """
# --> 143     client: Client = cls.from_file(
#     144         url,
#     145         headers=headers,
#     146         parameters=parameters,
#     147         modifier=modifier,
#     148         request_modifier=request_modifier,
#     149         stac_io=stac_io,
#     150     )
#     151     search_link = client.get_search_link()
#     152     # if there is a search link, but no conformsTo advertised, ignore
#     153     # conformance entirely
#     154     # NOTE: this behavior to be deprecated as implementations become conformant
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/pystac_client/client.py:197, in Client.from_file(cls, href, stac_io, headers, parameters, modifier, request_modifier)
#     190 else:
#     191     stac_io.update(
#     192         headers=headers,
#     193         parameters=parameters,
#     194         request_modifier=request_modifier,
#     195     )
# --> 197 client: Client = super().from_file(href, stac_io)
#     199 client._stac_io._conformance = client.extra_fields.get(  # type: ignore
#     200     "conformsTo", []
#     201 )
#     202 client.modifier = modifier
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/pystac/catalog.py:1273, in Catalog.from_file(cls, href, stac_io)
#    1270 if stac_io is None:
#    1271     stac_io = pystac.StacIO.default()
# -> 1273 result = super().from_file(href, stac_io)
#    1274 result._stac_io = stac_io
#    1276 return result
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/pystac/stac_object.py:621, in STACObject.from_file(cls, href, stac_io)
#     618 if cls == STACObject:
#     619     return cast(S, pystac.read_file(href))
# --> 621 href = make_posix_style(href)
#     623 if stac_io is None:
#     624     stac_io = pystac.StacIO.default()
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/pystac/utils.py:35, in make_posix_style(href)
#      25 def make_posix_style(href: HREF) -> str:
#      26     """Converts double back slashes and single back slashes to single forward
#      27     slashes for converting Windows paths to Posix style.
#      28
#    (...)
#      33         str : The converted href in string form.
#      34     """
# ---> 35     _href = str(os.fspath(href))
#      36     return _href.replace("\\\\", "/").replace("\\", "/")
#
# TypeError: expected str, bytes or os.PathLike object, not NoneType
